// %%
#include <iostream>

// %%
#include <opencog/util/Config.h>

// %%
#include <opencog/guile/SchemeEval.h>

// %%
#include <opencog/atomspace/AtomSpace.h>
// Out:
// In file included from input_line_22:1:
// In file included from /usr/local/include/opencog/atomspace/AtomSpace.h:31:
// In file included from /usr/local/include/opencog/truthvalue/TruthValue.h:34:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:529:12: error: redefinition of '_Map_base'
//     struct _Map_base { };
//            ^
// /usr/include/c++/5/bits/hashtable_policy.h:529:12: note: previous definition is here
//     struct _Map_base { };
//            ^
// In file included from input_line_22:1:
// In file included from /usr/local/include/opencog/atomspace/AtomSpace.h:31:
// In file included from /usr/local/include/opencog/truthvalue/TruthValue.h:34:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:678:12: error: redefinition of '_Insert_base'
//     struct _Insert_base
//            ^
// /usr/include/c++/5/bits/hashtable_policy.h:678:12: note: previous definition is here
//     struct _Insert_base
//            ^
// In file included from input_line_22:1:
// In file included from /usr/local/include/opencog/atomspace/AtomSpace.h:31:
// In file included from /usr/local/include/opencog/truthvalue/TruthValue.h:34:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:748:7: error: out-of-line definition of '_M_insert_range' does not match any declaration in
//       '_Insert_base<_Key, _Value, _Alloc, _ExtractKey, _Equal, _H1, _H2, _Hash,
//       _RehashPolicy, _Traits>'
//       _M_insert_range(_InputIterator __first, _InputIterator __last,
//       ^~~~~~~~~~~~~~~
// /usr/include/c++/5/bits/hashtable_policy.h:751:33: error: use of undeclared identifier '__hashtable'
//         using __rehash_type = typename __hashtable::__rehash_type;
//                                        ^
// /usr/include/c++/5/bits/hashtable_policy.h:751:46: error: expected a qualified name after 'typename'
//         using __rehash_type = typename __hashtable::__rehash_type;
//                                                     ^
// /usr/include/c++/5/bits/hashtable_policy.h:751:46: error: type-id cannot have a name
// /usr/include/c++/5/bits/hashtable_policy.h:752:34: error: use of undeclared identifier '__hashtable'
//         using __rehash_state = typename __hashtable::__rehash_state;
//                                         ^
// /usr/include/c++/5/bits/hashtable_policy.h:752:47: error: expected a qualified name after 'typename'
//         using __rehash_state = typename __hashtable::__rehash_state;
//                                                      ^
// /usr/include/c++/5/bits/hashtable_policy.h:752:47: error: type-id cannot have a name
// /usr/include/c++/5/bits/hashtable_policy.h:755:2: error: unknown type name 'size_type'
//         size_type __n_elt = __detail::__distance_fw(__first, __last);
//         ^
// /usr/include/c++/5/bits/hashtable_policy.h:757:2: error: unknown type name '__hashtable'
//         __hashtable& __h = _M_conjure_hashtable();
//         ^
// /usr/include/c++/5/bits/hashtable_policy.h:757:21: error: use of undeclared identifier '_M_conjure_hashtable'
//         __hashtable& __h = _M_conjure_hashtable();
//                            ^
// /usr/include/c++/5/bits/hashtable_policy.h:758:2: error: unknown type name '__rehash_type'
//         __rehash_type& __rehash = __h._M_rehash_policy;
//         ^
// /usr/include/c++/5/bits/hashtable_policy.h:759:8: error: unknown type name '__rehash_state'
//         const __rehash_state& __saved_state = __rehash._M_state();
//               ^
// /usr/include/c++/5/bits/hashtable_policy.h:768:40: error: use of undeclared identifier '__unique_keys'
//           __h._M_insert(*__first, __node_gen, __unique_keys());
//                                               ^
// /usr/include/c++/5/bits/hashtable_policy.h:780:32: error: template parameter redefines default argument
//            bool _Constant_iterators = _Traits::__constant_iterators::value,
//                                       ^
// /usr/include/c++/5/bits/hashtable_policy.h:780:32: note: previous default template argument defined here
//            bool _Constant_iterators = _Traits::__constant_iterators::value,
//                                       ^
// In file included from input_line_22:1:
// In file included from /usr/local/include/opencog/atomspace/AtomSpace.h:31:
// In file included from /usr/local/include/opencog/truthvalue/TruthValue.h:34:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:781:25: error: template parameter redefines default argument
//            bool _Unique_keys = _Traits::__unique_keys::value>
//                                ^
// /usr/include/c++/5/bits/hashtable_policy.h:781:25: note: previous default template argument defined here
//            bool _Unique_keys = _Traits::__unique_keys::value>
//                                ^
// In file included from input_line_22:1:
// In file included from /usr/local/include/opencog/atomspace/AtomSpace.h:31:
// In file included from /usr/local/include/opencog/truthvalue/TruthValue.h:34:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:879:48: error: no type named 'value_type' in
//       'std::__detail::_Insert_base<std::__cxx11::basic_string<char>,
//       std::pair<const std::__cxx11::basic_string<char>, unsigned short>,
//       std::allocator<std::pair<const std::__cxx11::basic_string<char>, unsigned
//       short> >, std::__detail::_Select1st,
//       std::equal_to<std::__cxx11::basic_string<char> >,
//       std::hash<std::__cxx11::string>, std::__detail::_Mod_range_hashing,
//       std::__detail::_Default_ranged_hash, std::__detail::_Prime_rehash_policy,
//       std::__detail::_Hashtable_traits<true, false, true> >'
//       using value_type = typename __base_type::value_type;
//                          ~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~
// /usr/include/c++/5/bits/hashtable.h:175:14: note: in instantiation of template class
//       'std::__detail::_Insert<std::__cxx11::basic_string<char>, std::pair<const
//       std::__cxx11::basic_string<char>, unsigned short>,
//       std::allocator<std::pair<const std::__cxx11::basic_string<char>, unsigned
//       short> >, std::__detail::_Select1st,
//       std::equal_to<std::__cxx11::basic_string<char> >,
//       std::hash<std::__cxx11::string>, std::__detail::_Mod_range_hashing,
//       std::__detail::_Default_ranged_hash, std::__detail::_Prime_rehash_policy,
//       std::__detail::_Hashtable_traits<true, false, true>, false, true>'
//       requested here
//       public __detail::_Insert<_Key, _Value, _Alloc, _ExtractKey, _Equal,
//              ^
// /usr/include/c++/5/bits/unordered_map.h:101:18: note: in instantiation of template class
//       'std::_Hashtable<std::__cxx11::basic_string<char>, std::pair<const
//       std::__cxx11::basic_string<char>, unsigned short>,
//       std::allocator<std::pair<const std::__cxx11::basic_string<char>, unsigned
//       short> >, std::__detail::_Select1st,
//       std::equal_to<std::__cxx11::basic_string<char> >,
//       std::hash<std::__cxx11::string>, std::__detail::_Mod_range_hashing,
//       std::__detail::_Default_ranged_hash, std::__detail::_Prime_rehash_policy,
//       std::__detail::_Hashtable_traits<true, false, true> >' requested here
//       _Hashtable _M_h;
//                  ^
// /usr/local/include/opencog/atoms/proto/NameServer.h:72:43: note: in instantiation of template class
//       'std::unordered_map<std::__cxx11::basic_string<char>, unsigned short,
//       std::hash<std::__cxx11::string>,
//       std::equal_to<std::__cxx11::basic_string<char> >,
//       std::allocator<std::pair<const std::__cxx11::basic_string<char>, unsigned
//       short> > >' requested here
//     std::unordered_map<std::string, Type> name2CodeMap;
//                                           ^
// In file included from input_line_22:1:
// In file included from /usr/local/include/opencog/atomspace/AtomSpace.h:31:
// In file included from /usr/local/include/opencog/truthvalue/TruthValue.h:34:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:880:46: error: no type named 'iterator' in
//       'std::__detail::_Insert_base<std::__cxx11::basic_string<char>,
//       std::pair<const std::__cxx11::basic_string<char>, unsigned short>,
//       std::allocator<std::pair<const std::__cxx11::basic_string<char>, unsigned
//       short> >, std::__detail::_Select1st,
//       std::equal_to<std::__cxx11::basic_string<char> >,
//       std::hash<std::__cxx11::string>, std::__detail::_Mod_range_hashing,
//       std::__detail::_Default_ranged_hash, std::__detail::_Prime_rehash_policy,
//       std::__detail::_Hashtable_traits<true, false, true> >'
//       using iterator = typename __base_type::iterator;
//                        ~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~
// fatal error: too many errors emitted, stopping now [-ferror-limit=]
// Interpreter Error:

// %%
#include <opencog/truthvalue/AttentionValue.h>
// Out:
// In file included from input_line_23:1:
// In file included from /usr/local/include/opencog/truthvalue/AttentionValue.h:31:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:529:12: error: redefinition of '_Map_base'
//     struct _Map_base { };
//            ^
// /usr/include/c++/5/bits/hashtable_policy.h:529:12: note: previous definition is here
//     struct _Map_base { };
//            ^
// In file included from input_line_23:1:
// In file included from /usr/local/include/opencog/truthvalue/AttentionValue.h:31:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:678:12: error: redefinition of '_Insert_base'
//     struct _Insert_base
//            ^
// /usr/include/c++/5/bits/hashtable_policy.h:678:12: note: previous definition is here
//     struct _Insert_base
//            ^
// In file included from input_line_23:1:
// In file included from /usr/local/include/opencog/truthvalue/AttentionValue.h:31:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:748:7: error: out-of-line definition of '_M_insert_range' does not match any declaration in
//       '_Insert_base<_Key, _Value, _Alloc, _ExtractKey, _Equal, _H1, _H2, _Hash,
//       _RehashPolicy, _Traits>'
//       _M_insert_range(_InputIterator __first, _InputIterator __last,
//       ^~~~~~~~~~~~~~~
// /usr/include/c++/5/bits/hashtable_policy.h:751:33: error: use of undeclared identifier '__hashtable'
//         using __rehash_type = typename __hashtable::__rehash_type;
//                                        ^
// /usr/include/c++/5/bits/hashtable_policy.h:751:46: error: expected a qualified name after 'typename'
//         using __rehash_type = typename __hashtable::__rehash_type;
//                                                     ^
// /usr/include/c++/5/bits/hashtable_policy.h:751:46: error: type-id cannot have a name
// /usr/include/c++/5/bits/hashtable_policy.h:752:34: error: use of undeclared identifier '__hashtable'
//         using __rehash_state = typename __hashtable::__rehash_state;
//                                         ^
// /usr/include/c++/5/bits/hashtable_policy.h:752:47: error: expected a qualified name after 'typename'
//         using __rehash_state = typename __hashtable::__rehash_state;
//                                                      ^
// /usr/include/c++/5/bits/hashtable_policy.h:752:47: error: type-id cannot have a name
// /usr/include/c++/5/bits/hashtable_policy.h:755:2: error: unknown type name 'size_type'
//         size_type __n_elt = __detail::__distance_fw(__first, __last);
//         ^
// /usr/include/c++/5/bits/hashtable_policy.h:757:2: error: unknown type name '__hashtable'
//         __hashtable& __h = _M_conjure_hashtable();
//         ^
// /usr/include/c++/5/bits/hashtable_policy.h:757:21: error: use of undeclared identifier '_M_conjure_hashtable'
//         __hashtable& __h = _M_conjure_hashtable();
//                            ^
// /usr/include/c++/5/bits/hashtable_policy.h:758:2: error: unknown type name '__rehash_type'
//         __rehash_type& __rehash = __h._M_rehash_policy;
//         ^
// /usr/include/c++/5/bits/hashtable_policy.h:759:8: error: unknown type name '__rehash_state'
//         const __rehash_state& __saved_state = __rehash._M_state();
//               ^
// /usr/include/c++/5/bits/hashtable_policy.h:768:40: error: use of undeclared identifier '__unique_keys'
//           __h._M_insert(*__first, __node_gen, __unique_keys());
//                                               ^
// /usr/include/c++/5/bits/hashtable_policy.h:780:32: error: template parameter redefines default argument
//            bool _Constant_iterators = _Traits::__constant_iterators::value,
//                                       ^
// /usr/include/c++/5/bits/hashtable_policy.h:780:32: note: previous default template argument defined here
//            bool _Constant_iterators = _Traits::__constant_iterators::value,
//                                       ^
// In file included from input_line_23:1:
// In file included from /usr/local/include/opencog/truthvalue/AttentionValue.h:31:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:781:25: error: template parameter redefines default argument
//            bool _Unique_keys = _Traits::__unique_keys::value>
//                                ^
// /usr/include/c++/5/bits/hashtable_policy.h:781:25: note: previous default template argument defined here
//            bool _Unique_keys = _Traits::__unique_keys::value>
//                                ^
// In file included from input_line_23:1:
// In file included from /usr/local/include/opencog/truthvalue/AttentionValue.h:31:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:879:48: error: no type named 'value_type' in
//       'std::__detail::_Insert_base<std::__cxx11::basic_string<char>,
//       std::pair<const std::__cxx11::basic_string<char>, unsigned short>,
//       std::allocator<std::pair<const std::__cxx11::basic_string<char>, unsigned
//       short> >, std::__detail::_Select1st,
//       std::equal_to<std::__cxx11::basic_string<char> >,
//       std::hash<std::__cxx11::string>, std::__detail::_Mod_range_hashing,
//       std::__detail::_Default_ranged_hash, std::__detail::_Prime_rehash_policy,
//       std::__detail::_Hashtable_traits<true, false, true> >'
//       using value_type = typename __base_type::value_type;
//                          ~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~
// /usr/include/c++/5/bits/hashtable.h:175:14: note: in instantiation of template class
//       'std::__detail::_Insert<std::__cxx11::basic_string<char>, std::pair<const
//       std::__cxx11::basic_string<char>, unsigned short>,
//       std::allocator<std::pair<const std::__cxx11::basic_string<char>, unsigned
//       short> >, std::__detail::_Select1st,
//       std::equal_to<std::__cxx11::basic_string<char> >,
//       std::hash<std::__cxx11::string>, std::__detail::_Mod_range_hashing,
//       std::__detail::_Default_ranged_hash, std::__detail::_Prime_rehash_policy,
//       std::__detail::_Hashtable_traits<true, false, true>, false, true>'
//       requested here
//       public __detail::_Insert<_Key, _Value, _Alloc, _ExtractKey, _Equal,
//              ^
// /usr/include/c++/5/bits/unordered_map.h:101:18: note: in instantiation of template class
//       'std::_Hashtable<std::__cxx11::basic_string<char>, std::pair<const
//       std::__cxx11::basic_string<char>, unsigned short>,
//       std::allocator<std::pair<const std::__cxx11::basic_string<char>, unsigned
//       short> >, std::__detail::_Select1st,
//       std::equal_to<std::__cxx11::basic_string<char> >,
//       std::hash<std::__cxx11::string>, std::__detail::_Mod_range_hashing,
//       std::__detail::_Default_ranged_hash, std::__detail::_Prime_rehash_policy,
//       std::__detail::_Hashtable_traits<true, false, true> >' requested here
//       _Hashtable _M_h;
//                  ^
// /usr/local/include/opencog/atoms/proto/NameServer.h:72:43: note: in instantiation of template class
//       'std::unordered_map<std::__cxx11::basic_string<char>, unsigned short,
//       std::hash<std::__cxx11::string>,
//       std::equal_to<std::__cxx11::basic_string<char> >,
//       std::allocator<std::pair<const std::__cxx11::basic_string<char>, unsigned
//       short> > >' requested here
//     std::unordered_map<std::string, Type> name2CodeMap;
//                                           ^
// In file included from input_line_23:1:
// In file included from /usr/local/include/opencog/truthvalue/AttentionValue.h:31:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:880:46: error: no type named 'iterator' in
//       'std::__detail::_Insert_base<std::__cxx11::basic_string<char>,
//       std::pair<const std::__cxx11::basic_string<char>, unsigned short>,
//       std::allocator<std::pair<const std::__cxx11::basic_string<char>, unsigned
//       short> >, std::__detail::_Select1st,
//       std::equal_to<std::__cxx11::basic_string<char> >,
//       std::hash<std::__cxx11::string>, std::__detail::_Mod_range_hashing,
//       std::__detail::_Default_ranged_hash, std::__detail::_Prime_rehash_policy,
//       std::__detail::_Hashtable_traits<true, false, true> >'
//       using iterator = typename __base_type::iterator;
//                        ~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~
// fatal error: too many errors emitted, stopping now [-ferror-limit=]
// Interpreter Error:

// %%
#include <opencog/truthvalue/SimpleTruthValue.h>
// Out:
// In file included from input_line_24:1:
// In file included from /usr/local/include/opencog/truthvalue/SimpleTruthValue.h:30:
// In file included from /usr/local/include/opencog/truthvalue/TruthValue.h:34:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:529:12: error: redefinition of '_Map_base'
//     struct _Map_base { };
//            ^
// /usr/include/c++/5/bits/hashtable_policy.h:529:12: note: previous definition is here
//     struct _Map_base { };
//            ^
// In file included from input_line_24:1:
// In file included from /usr/local/include/opencog/truthvalue/SimpleTruthValue.h:30:
// In file included from /usr/local/include/opencog/truthvalue/TruthValue.h:34:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:678:12: error: redefinition of '_Insert_base'
//     struct _Insert_base
//            ^
// /usr/include/c++/5/bits/hashtable_policy.h:678:12: note: previous definition is here
//     struct _Insert_base
//            ^
// In file included from input_line_24:1:
// In file included from /usr/local/include/opencog/truthvalue/SimpleTruthValue.h:30:
// In file included from /usr/local/include/opencog/truthvalue/TruthValue.h:34:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:748:7: error: out-of-line definition of '_M_insert_range' does not match any declaration in
//       '_Insert_base<_Key, _Value, _Alloc, _ExtractKey, _Equal, _H1, _H2, _Hash,
//       _RehashPolicy, _Traits>'
//       _M_insert_range(_InputIterator __first, _InputIterator __last,
//       ^~~~~~~~~~~~~~~
// /usr/include/c++/5/bits/hashtable_policy.h:751:33: error: use of undeclared identifier '__hashtable'
//         using __rehash_type = typename __hashtable::__rehash_type;
//                                        ^
// /usr/include/c++/5/bits/hashtable_policy.h:751:46: error: expected a qualified name after 'typename'
//         using __rehash_type = typename __hashtable::__rehash_type;
//                                                     ^
// /usr/include/c++/5/bits/hashtable_policy.h:751:46: error: type-id cannot have a name
// /usr/include/c++/5/bits/hashtable_policy.h:752:34: error: use of undeclared identifier '__hashtable'
//         using __rehash_state = typename __hashtable::__rehash_state;
//                                         ^
// /usr/include/c++/5/bits/hashtable_policy.h:752:47: error: expected a qualified name after 'typename'
//         using __rehash_state = typename __hashtable::__rehash_state;
//                                                      ^
// /usr/include/c++/5/bits/hashtable_policy.h:752:47: error: type-id cannot have a name
// /usr/include/c++/5/bits/hashtable_policy.h:755:2: error: unknown type name 'size_type'
//         size_type __n_elt = __detail::__distance_fw(__first, __last);
//         ^
// /usr/include/c++/5/bits/hashtable_policy.h:757:2: error: unknown type name '__hashtable'
//         __hashtable& __h = _M_conjure_hashtable();
//         ^
// /usr/include/c++/5/bits/hashtable_policy.h:757:21: error: use of undeclared identifier '_M_conjure_hashtable'
//         __hashtable& __h = _M_conjure_hashtable();
//                            ^
// /usr/include/c++/5/bits/hashtable_policy.h:758:2: error: unknown type name '__rehash_type'
//         __rehash_type& __rehash = __h._M_rehash_policy;
//         ^
// /usr/include/c++/5/bits/hashtable_policy.h:759:8: error: unknown type name '__rehash_state'
//         const __rehash_state& __saved_state = __rehash._M_state();
//               ^
// /usr/include/c++/5/bits/hashtable_policy.h:768:40: error: use of undeclared identifier '__unique_keys'
//           __h._M_insert(*__first, __node_gen, __unique_keys());
//                                               ^
// /usr/include/c++/5/bits/hashtable_policy.h:780:32: error: template parameter redefines default argument
//            bool _Constant_iterators = _Traits::__constant_iterators::value,
//                                       ^
// /usr/include/c++/5/bits/hashtable_policy.h:780:32: note: previous default template argument defined here
//            bool _Constant_iterators = _Traits::__constant_iterators::value,
//                                       ^
// In file included from input_line_24:1:
// In file included from /usr/local/include/opencog/truthvalue/SimpleTruthValue.h:30:
// In file included from /usr/local/include/opencog/truthvalue/TruthValue.h:34:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:781:25: error: template parameter redefines default argument
//            bool _Unique_keys = _Traits::__unique_keys::value>
//                                ^
// /usr/include/c++/5/bits/hashtable_policy.h:781:25: note: previous default template argument defined here
//            bool _Unique_keys = _Traits::__unique_keys::value>
//                                ^
// In file included from input_line_24:1:
// In file included from /usr/local/include/opencog/truthvalue/SimpleTruthValue.h:30:
// In file included from /usr/local/include/opencog/truthvalue/TruthValue.h:34:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:879:48: error: no type named 'value_type' in
//       'std::__detail::_Insert_base<std::__cxx11::basic_string<char>,
//       std::pair<const std::__cxx11::basic_string<char>, unsigned short>,
//       std::allocator<std::pair<const std::__cxx11::basic_string<char>, unsigned
//       short> >, std::__detail::_Select1st,
//       std::equal_to<std::__cxx11::basic_string<char> >,
//       std::hash<std::__cxx11::string>, std::__detail::_Mod_range_hashing,
//       std::__detail::_Default_ranged_hash, std::__detail::_Prime_rehash_policy,
//       std::__detail::_Hashtable_traits<true, false, true> >'
//       using value_type = typename __base_type::value_type;
//                          ~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~
// /usr/include/c++/5/bits/hashtable.h:175:14: note: in instantiation of template class
//       'std::__detail::_Insert<std::__cxx11::basic_string<char>, std::pair<const
//       std::__cxx11::basic_string<char>, unsigned short>,
//       std::allocator<std::pair<const std::__cxx11::basic_string<char>, unsigned
//       short> >, std::__detail::_Select1st,
//       std::equal_to<std::__cxx11::basic_string<char> >,
//       std::hash<std::__cxx11::string>, std::__detail::_Mod_range_hashing,
//       std::__detail::_Default_ranged_hash, std::__detail::_Prime_rehash_policy,
//       std::__detail::_Hashtable_traits<true, false, true>, false, true>'
//       requested here
//       public __detail::_Insert<_Key, _Value, _Alloc, _ExtractKey, _Equal,
//              ^
// /usr/include/c++/5/bits/unordered_map.h:101:18: note: in instantiation of template class
//       'std::_Hashtable<std::__cxx11::basic_string<char>, std::pair<const
//       std::__cxx11::basic_string<char>, unsigned short>,
//       std::allocator<std::pair<const std::__cxx11::basic_string<char>, unsigned
//       short> >, std::__detail::_Select1st,
//       std::equal_to<std::__cxx11::basic_string<char> >,
//       std::hash<std::__cxx11::string>, std::__detail::_Mod_range_hashing,
//       std::__detail::_Default_ranged_hash, std::__detail::_Prime_rehash_policy,
//       std::__detail::_Hashtable_traits<true, false, true> >' requested here
//       _Hashtable _M_h;
//                  ^
// /usr/local/include/opencog/atoms/proto/NameServer.h:72:43: note: in instantiation of template class
//       'std::unordered_map<std::__cxx11::basic_string<char>, unsigned short,
//       std::hash<std::__cxx11::string>,
//       std::equal_to<std::__cxx11::basic_string<char> >,
//       std::allocator<std::pair<const std::__cxx11::basic_string<char>, unsigned
//       short> > >' requested here
//     std::unordered_map<std::string, Type> name2CodeMap;
//                                           ^
// In file included from input_line_24:1:
// In file included from /usr/local/include/opencog/truthvalue/SimpleTruthValue.h:30:
// In file included from /usr/local/include/opencog/truthvalue/TruthValue.h:34:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:880:46: error: no type named 'iterator' in
//       'std::__detail::_Insert_base<std::__cxx11::basic_string<char>,
//       std::pair<const std::__cxx11::basic_string<char>, unsigned short>,
//       std::allocator<std::pair<const std::__cxx11::basic_string<char>, unsigned
//       short> >, std::__detail::_Select1st,
//       std::equal_to<std::__cxx11::basic_string<char> >,
//       std::hash<std::__cxx11::string>, std::__detail::_Mod_range_hashing,
//       std::__detail::_Default_ranged_hash, std::__detail::_Prime_rehash_policy,
//       std::__detail::_Hashtable_traits<true, false, true> >'
//       using iterator = typename __base_type::iterator;
//                        ~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~
// fatal error: too many errors emitted, stopping now [-ferror-limit=]
// Interpreter Error:

// %%
#include <opencog/truthvalue/TruthValue.h>
// Out:
// In file included from input_line_25:1:
// In file included from /usr/local/include/opencog/truthvalue/TruthValue.h:34:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:529:12: error: redefinition of '_Map_base'
//     struct _Map_base { };
//            ^
// /usr/include/c++/5/bits/hashtable_policy.h:529:12: note: previous definition is here
//     struct _Map_base { };
//            ^
// In file included from input_line_25:1:
// In file included from /usr/local/include/opencog/truthvalue/TruthValue.h:34:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:678:12: error: redefinition of '_Insert_base'
//     struct _Insert_base
//            ^
// /usr/include/c++/5/bits/hashtable_policy.h:678:12: note: previous definition is here
//     struct _Insert_base
//            ^
// In file included from input_line_25:1:
// In file included from /usr/local/include/opencog/truthvalue/TruthValue.h:34:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:748:7: error: out-of-line definition of '_M_insert_range' does not match any declaration in
//       '_Insert_base<_Key, _Value, _Alloc, _ExtractKey, _Equal, _H1, _H2, _Hash,
//       _RehashPolicy, _Traits>'
//       _M_insert_range(_InputIterator __first, _InputIterator __last,
//       ^~~~~~~~~~~~~~~
// /usr/include/c++/5/bits/hashtable_policy.h:751:33: error: use of undeclared identifier '__hashtable'
//         using __rehash_type = typename __hashtable::__rehash_type;
//                                        ^
// /usr/include/c++/5/bits/hashtable_policy.h:751:46: error: expected a qualified name after 'typename'
//         using __rehash_type = typename __hashtable::__rehash_type;
//                                                     ^
// /usr/include/c++/5/bits/hashtable_policy.h:751:46: error: type-id cannot have a name
// /usr/include/c++/5/bits/hashtable_policy.h:752:34: error: use of undeclared identifier '__hashtable'
//         using __rehash_state = typename __hashtable::__rehash_state;
//                                         ^
// /usr/include/c++/5/bits/hashtable_policy.h:752:47: error: expected a qualified name after 'typename'
//         using __rehash_state = typename __hashtable::__rehash_state;
//                                                      ^
// /usr/include/c++/5/bits/hashtable_policy.h:752:47: error: type-id cannot have a name
// /usr/include/c++/5/bits/hashtable_policy.h:755:2: error: unknown type name 'size_type'
//         size_type __n_elt = __detail::__distance_fw(__first, __last);
//         ^
// /usr/include/c++/5/bits/hashtable_policy.h:757:2: error: unknown type name '__hashtable'
//         __hashtable& __h = _M_conjure_hashtable();
//         ^
// /usr/include/c++/5/bits/hashtable_policy.h:757:21: error: use of undeclared identifier '_M_conjure_hashtable'
//         __hashtable& __h = _M_conjure_hashtable();
//                            ^
// /usr/include/c++/5/bits/hashtable_policy.h:758:2: error: unknown type name '__rehash_type'
//         __rehash_type& __rehash = __h._M_rehash_policy;
//         ^
// /usr/include/c++/5/bits/hashtable_policy.h:759:8: error: unknown type name '__rehash_state'
//         const __rehash_state& __saved_state = __rehash._M_state();
//               ^
// /usr/include/c++/5/bits/hashtable_policy.h:768:40: error: use of undeclared identifier '__unique_keys'
//           __h._M_insert(*__first, __node_gen, __unique_keys());
//                                               ^
// /usr/include/c++/5/bits/hashtable_policy.h:780:32: error: template parameter redefines default argument
//            bool _Constant_iterators = _Traits::__constant_iterators::value,
//                                       ^
// /usr/include/c++/5/bits/hashtable_policy.h:780:32: note: previous default template argument defined here
//            bool _Constant_iterators = _Traits::__constant_iterators::value,
//                                       ^
// In file included from input_line_25:1:
// In file included from /usr/local/include/opencog/truthvalue/TruthValue.h:34:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:781:25: error: template parameter redefines default argument
//            bool _Unique_keys = _Traits::__unique_keys::value>
//                                ^
// /usr/include/c++/5/bits/hashtable_policy.h:781:25: note: previous default template argument defined here
//            bool _Unique_keys = _Traits::__unique_keys::value>
//                                ^
// In file included from input_line_25:1:
// In file included from /usr/local/include/opencog/truthvalue/TruthValue.h:34:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:879:48: error: no type named 'value_type' in
//       'std::__detail::_Insert_base<std::__cxx11::basic_string<char>,
//       std::pair<const std::__cxx11::basic_string<char>, unsigned short>,
//       std::allocator<std::pair<const std::__cxx11::basic_string<char>, unsigned
//       short> >, std::__detail::_Select1st,
//       std::equal_to<std::__cxx11::basic_string<char> >,
//       std::hash<std::__cxx11::string>, std::__detail::_Mod_range_hashing,
//       std::__detail::_Default_ranged_hash, std::__detail::_Prime_rehash_policy,
//       std::__detail::_Hashtable_traits<true, false, true> >'
//       using value_type = typename __base_type::value_type;
//                          ~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~
// /usr/include/c++/5/bits/hashtable.h:175:14: note: in instantiation of template class
//       'std::__detail::_Insert<std::__cxx11::basic_string<char>, std::pair<const
//       std::__cxx11::basic_string<char>, unsigned short>,
//       std::allocator<std::pair<const std::__cxx11::basic_string<char>, unsigned
//       short> >, std::__detail::_Select1st,
//       std::equal_to<std::__cxx11::basic_string<char> >,
//       std::hash<std::__cxx11::string>, std::__detail::_Mod_range_hashing,
//       std::__detail::_Default_ranged_hash, std::__detail::_Prime_rehash_policy,
//       std::__detail::_Hashtable_traits<true, false, true>, false, true>'
//       requested here
//       public __detail::_Insert<_Key, _Value, _Alloc, _ExtractKey, _Equal,
//              ^
// /usr/include/c++/5/bits/unordered_map.h:101:18: note: in instantiation of template class
//       'std::_Hashtable<std::__cxx11::basic_string<char>, std::pair<const
//       std::__cxx11::basic_string<char>, unsigned short>,
//       std::allocator<std::pair<const std::__cxx11::basic_string<char>, unsigned
//       short> >, std::__detail::_Select1st,
//       std::equal_to<std::__cxx11::basic_string<char> >,
//       std::hash<std::__cxx11::string>, std::__detail::_Mod_range_hashing,
//       std::__detail::_Default_ranged_hash, std::__detail::_Prime_rehash_policy,
//       std::__detail::_Hashtable_traits<true, false, true> >' requested here
//       _Hashtable _M_h;
//                  ^
// /usr/local/include/opencog/atoms/proto/NameServer.h:72:43: note: in instantiation of template class
//       'std::unordered_map<std::__cxx11::basic_string<char>, unsigned short,
//       std::hash<std::__cxx11::string>,
//       std::equal_to<std::__cxx11::basic_string<char> >,
//       std::allocator<std::pair<const std::__cxx11::basic_string<char>, unsigned
//       short> > >' requested here
//     std::unordered_map<std::string, Type> name2CodeMap;
//                                           ^
// In file included from input_line_25:1:
// In file included from /usr/local/include/opencog/truthvalue/TruthValue.h:34:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:880:46: error: no type named 'iterator' in
//       'std::__detail::_Insert_base<std::__cxx11::basic_string<char>,
//       std::pair<const std::__cxx11::basic_string<char>, unsigned short>,
//       std::allocator<std::pair<const std::__cxx11::basic_string<char>, unsigned
//       short> >, std::__detail::_Select1st,
//       std::equal_to<std::__cxx11::basic_string<char> >,
//       std::hash<std::__cxx11::string>, std::__detail::_Mod_range_hashing,
//       std::__detail::_Default_ranged_hash, std::__detail::_Prime_rehash_policy,
//       std::__detail::_Hashtable_traits<true, false, true> >'
//       using iterator = typename __base_type::iterator;
//                        ~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~
// fatal error: too many errors emitted, stopping now [-ferror-limit=]
// Interpreter Error:

// %%
#include <opencog/rule-engine/forwardchainer/ForwardChainer.h>
// Out:
// In file included from input_line_13:1:
// In file included from /usr/local/include/opencog/rule-engine/forwardchainer/ForwardChainer.h:27:
// In file included from /usr/local/include/opencog/rule-engine/URECommons.h:29:
// In file included from /usr/local/include/opencog/atomspace/AtomSpace.h:31:
// In file included from /usr/local/include/opencog/truthvalue/TruthValue.h:34:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:529:12: error: redefinition of '_Map_base'
//     struct _Map_base { };
//            ^
// /usr/include/c++/5/bits/hashtable_policy.h:529:12: note: previous definition is here
//     struct _Map_base { };
//            ^
// In file included from input_line_13:1:
// In file included from /usr/local/include/opencog/rule-engine/forwardchainer/ForwardChainer.h:27:
// In file included from /usr/local/include/opencog/rule-engine/URECommons.h:29:
// In file included from /usr/local/include/opencog/atomspace/AtomSpace.h:31:
// In file included from /usr/local/include/opencog/truthvalue/TruthValue.h:34:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:678:12: error: redefinition of '_Insert_base'
//     struct _Insert_base
//            ^
// /usr/include/c++/5/bits/hashtable_policy.h:678:12: note: previous definition is here
//     struct _Insert_base
//            ^
// In file included from input_line_13:1:
// In file included from /usr/local/include/opencog/rule-engine/forwardchainer/ForwardChainer.h:27:
// In file included from /usr/local/include/opencog/rule-engine/URECommons.h:29:
// In file included from /usr/local/include/opencog/atomspace/AtomSpace.h:31:
// In file included from /usr/local/include/opencog/truthvalue/TruthValue.h:34:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:748:7: error: out-of-line definition of '_M_insert_range' does not match any declaration in
//       '_Insert_base<_Key, _Value, _Alloc, _ExtractKey, _Equal, _H1, _H2, _Hash,
//       _RehashPolicy, _Traits>'
//       _M_insert_range(_InputIterator __first, _InputIterator __last,
//       ^~~~~~~~~~~~~~~
// /usr/include/c++/5/bits/hashtable_policy.h:751:33: error: use of undeclared identifier '__hashtable'
//         using __rehash_type = typename __hashtable::__rehash_type;
//                                        ^
// /usr/include/c++/5/bits/hashtable_policy.h:751:46: error: expected a qualified name after 'typename'
//         using __rehash_type = typename __hashtable::__rehash_type;
//                                                     ^
// /usr/include/c++/5/bits/hashtable_policy.h:751:46: error: type-id cannot have a name
// /usr/include/c++/5/bits/hashtable_policy.h:752:34: error: use of undeclared identifier '__hashtable'
//         using __rehash_state = typename __hashtable::__rehash_state;
//                                         ^
// /usr/include/c++/5/bits/hashtable_policy.h:752:47: error: expected a qualified name after 'typename'
//         using __rehash_state = typename __hashtable::__rehash_state;
//                                                      ^
// /usr/include/c++/5/bits/hashtable_policy.h:752:47: error: type-id cannot have a name
// /usr/include/c++/5/bits/hashtable_policy.h:755:2: error: unknown type name 'size_type'
//         size_type __n_elt = __detail::__distance_fw(__first, __last);
//         ^
// /usr/include/c++/5/bits/hashtable_policy.h:757:2: error: use of undeclared identifier '__hashtable'; did you mean '_Hashtable'?
//         __hashtable& __h = _M_conjure_hashtable();
//         ^
// /usr/include/c++/5/bits/hashtable_policy.h:42:11: note: '_Hashtable' declared here
//     class _Hashtable;
//           ^
// /usr/include/c++/5/bits/hashtable_policy.h:757:2: error: use of undeclared identifier '__hashtable'; did you mean '_Hashtable'?
//         __hashtable& __h = _M_conjure_hashtable();
//         ^
// /usr/include/c++/5/bits/hashtable_policy.h:42:11: note: '_Hashtable' declared here
//     class _Hashtable;
//           ^
// /usr/include/c++/5/bits/hashtable_policy.h:757:2: error: unknown type name '__hashtable'
//         __hashtable& __h = _M_conjure_hashtable();
//         ^
// /usr/include/c++/5/bits/hashtable_policy.h:757:21: error: use of undeclared identifier '_M_conjure_hashtable'
//         __hashtable& __h = _M_conjure_hashtable();
//                            ^
// /usr/include/c++/5/bits/hashtable_policy.h:758:2: error: unknown type name '__rehash_type'
//         __rehash_type& __rehash = __h._M_rehash_policy;
//         ^
// /usr/include/c++/5/bits/hashtable_policy.h:759:8: error: unknown type name '__rehash_state'
//         const __rehash_state& __saved_state = __rehash._M_state();
//               ^
// /usr/include/c++/5/bits/hashtable_policy.h:768:40: error: use of undeclared identifier '__unique_keys'
//           __h._M_insert(*__first, __node_gen, __unique_keys());
//                                               ^
// /usr/include/c++/5/bits/hashtable_policy.h:780:32: error: template parameter redefines default argument
//            bool _Constant_iterators = _Traits::__constant_iterators::value,
//                                       ^
// /usr/include/c++/5/bits/hashtable_policy.h:780:32: note: previous default template argument defined here
//            bool _Constant_iterators = _Traits::__constant_iterators::value,
//                                       ^
// In file included from input_line_13:1:
// In file included from /usr/local/include/opencog/rule-engine/forwardchainer/ForwardChainer.h:27:
// In file included from /usr/local/include/opencog/rule-engine/URECommons.h:29:
// In file included from /usr/local/include/opencog/atomspace/AtomSpace.h:31:
// In file included from /usr/local/include/opencog/truthvalue/TruthValue.h:34:
// In file included from /usr/local/include/opencog/atoms/proto/FloatValue.h:27:
// In file included from /usr/local/include/opencog/atoms/proto/ProtoAtom.h:30:
// In file included from /usr/local/include/opencog/atoms/proto/NameServer.h:29:
// In file included from /usr/include/c++/5/unordered_map:47:
// In file included from /usr/include/c++/5/bits/hashtable.h:35:
// /usr/include/c++/5/bits/hashtable_policy.h:781:25: error: template parameter redefines default argument
//            bool _Unique_keys = _Traits::__unique_keys::value>
//                                ^
// /usr/include/c++/5/bits/hashtable_policy.h:781:25: note: previous default template argument defined here
//            bool _Unique_keys = _Traits::__unique_keys::value>
//                                ^
// fatal error: too many errors emitted, stopping now [-ferror-limit=]
// Interpreter Error:

// %%
#include <opencog/guile/load-file.h>
// Out:
// input_line_18:1:10: fatal error: 'opencog/guile/load-file.h' file not found
// #include <opencog/guile/load-file.h>
//          ^~~~~~~~~~~~~~~~~~~~~~~~~~~
// Interpreter Error:

// %%
using namespace opencog;
